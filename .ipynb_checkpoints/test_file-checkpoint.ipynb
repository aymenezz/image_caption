# %%
import matplotlib.pyplot as plt
# %matplotlib Inline 
import tensorflow as tf
from glob import glob
import pandas as pd
import os 
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import sequence
import cv2 as cv
import numpy as np
import pickle

# %%
filesImages=os.listdir('./validation_data/flickr8k_validation_set_500_images')
path_models=os.listdir('./models')

# %%
Sequential

# %%
print(filesImages)
print(path_models)
# Out:
# ['captions.csv', 'Images']
# ['caption_model_v1.1.1_keras.keras', 'caption_model_v1_1_1.h5', 'InceptionEF_model (1).h5', 'vocab.pickle']

# %%
df=pd.read_csv(f"./validation_data/flickr8k_validation_set_500_images/{filesImages[filesImages.index('captions.csv')]}")

# %%
captions_image=df.groupby('image')['caption'].apply(list).to_dict()

# %%
captions_image
# Out:
# {'1007129816_e794419615.jpg': ['A man wears an orange hat and glasses .',
#   'A man with glasses is wearing a beer can crocheted hat .',
#   'A man with gauges and glasses is wearing a Blitz hat .',
#   'The man with pierced ears is wearing glasses and an orange hat .',
#   'A man in an orange hat starring at something .'],
#  '1022454428_b6b660a67b.jpg': ['A couple with their newborn baby sitting under a tree facing a lake .',
#   'Couple with a baby sit outdoors next to their stroller .',
#   'A couple and an infant , being held by the male , sitting next to a pond with a near by stroller .',
#   'A man and woman care for an infant along the side of a body of water .',
#   'A couple sit on the grass with a baby and stroller .'],
#  '103195344_5d2dc613a3.jpg': ['The man with the backpack is sitting in a buildings courtyard in front of an art sculpture reading .',
#   'A man sitting in front of a metal sculpture in front of a building .',
#   'A man sits and reads a newspaper by a sculpture outside of an office building .',
#   'a man sits near a large statue .',
#   'A man in black is sitting next to a modern art structure in front of a glass building .'],
#  '1072153132_53d2bb1b60.jpg': ['A black and white dog catches a toy in midair .',
#   'A multicolor dog jumping to catch a tennis ball in a grassy field .',
#   'A dog leaps while chasing a tennis ball through a grassy field .',
#   'A dog is jumping to catch a object thrown at it ,',
#   'A dog and a tennis ball .'],
#  '1075881101_d55c46bece.jpg': ['A person covered in soapy water is getting cleaned off .',
#   'A child covered in foam is climbing on a black inflatable ramp .',
#   'a boy cleans the bubbles off his face .',
#   'A boy covered in suds has his face wiped clean .',
#   'A boy is covered in bubbles .'],
#  '109260216_85b0be5378.jpg': ['A person is climbing a rock while holding onto a white rope .',
#   'A person rappels down a steep incline .',
#   'A person wearing a red vest climbs up a steep rock .',
#   'A person climbs a tall , flat mountain while holding onto a safety rope .',
#   'A person climbing down a sheer rock cliff using a rope'],
#  '1100214449_d10861e633.jpg': ['A happy boy is jumping in front OD city fountain .',
#   'A little boy is playfully jumping off the side of a fountain .',
#   'A boy in s striped shirt is jumping in front of a water fountain .',
#   'A little boy is jumping in front of a fountain .',
#   'A boy is jumping off the side of a running stone water fountain in front of a building .'],
#  '1130369873_d80a1aa59c.jpg': ['A brown dog splashes in the water while carrying a ball in its mouth .',
#   'A brown dog swims through water outdoors with a tennis ball in its mouth .',
#   'Brown dog with tennis ball in mouth , in water and bushes .',
#   'A brown dog is running through neck-deep water carrying a tennis ball .',
#   'A red dog , holding a ball , splashes through vegetation filled water .'],
#  '1177994172_10d143cb8d.jpg': ['Two young boys are squirting water at each other .',
#   'Two boys are squirting water guns at each other .',
#   'Two blonde boys , one in a camouflage shirt and the other in blue , are having a water fight .',
#   'Two children wearing jeans squirt water at each other .',
#   'Two boys spraying each other with water'],
#  '1204996216_71d7519d9a.jpg': ['A child is on a bench with arms stretched out .',
#   'A little boy lies down on a picnic table bench .',
#   'A boy lays on a picnic table bench .',
#   'A little boy in a red shirt sitting on a wooden picnic table bench .',
#   'A child is laying down on a wooden bench .'],
#  '1247181182_35cabd76f3.jpg': ['a man sits on a rock .',
#   'A man sitting on a cliff in the mountains .',
#   'The man is sitting at the top of a rocky mountain .',
#   'A man wearing a blue shirt crouches on a rocky cliff .',
#   'A person posing on a mountaintop .'],
#  '1255504166_f2437febcb.jpg': ['A young boy plays in the water with the mountains in the background .',
#   'A child is splashing in the water',
#   'A small child in water with a splash encircling him while the white clouds float over the mountains .',
#   'A boy playing in a lake',
#   'A little boy is playing in the water with a beautiful sunset and mountains in the background .'],
#  '1287073593_f3d2a62455.jpg': ['Dogsled rider pulled past flags on snowy hill .',
#   'Five sled dogs are pulling a person on a sled , through the snow .',
#   'The man is mushing his dogs on a snow trail',
#   'Dogs pulling a sled in a sled race .',
#   'A group of dogs pull a person on a dog sled up a hill .'],
#  '129599450_cab4e77343.jpg': ['A person hikes on a mountain .',
#   'A man is hiking on a mountain path with an American flag on his backpack .',
#   'A hiker with an American flag on his backpack walks through the woods .',
#   'A hiker carring an American flag .',
#   'A backpacker in the mountains wearing an american flag .'],
#  '1298295313_db1f4c6522.jpg': ['A boy diving backward off a pier in a large lake .',
#   'A boy is holding his nose and jumping off a diving board backwards into a lake .',
#   'A blonde boy wearing a blue life vest and camo shorts jumps off a diveboard into a blue lake .',
#   'A boy in a blue life jacket jumps into the water .',
#   'A boy in a blue life jacket jumps off a board into the lake .'],
#  '1299459550_1fd5594fa2.jpg': ['A toddler in blue shorts is laying face down on the wet ground .',
#   'A boy in swimming trunks .',
#   'The boy in swim trunks is laying face down on a watery pavement .',
#   'Boy in shorts , face down in shallow , reflective water .',
#   'A young boy laying face down in water .'],
#  '1350811702_2ce7cfd0c5.jpg': ['Young boy wearing waders standing on a dock fishing , other people are in the background .',
#   'People fishing over white fence',
#   'Young boy standing next to water casting his fishing rod with others next to him .',
#   'A young boy casting his fishing line off a pier',
#   'Children fishing off a bridge'],
#  '1368383637_614646cc4a.jpg': ['People stand inside a windowed structure .',
#   'Three people and a black and white dog in bright industrial corridor .',
#   'Three people enjoying the view in a modern building .',
#   'People stand in corridor looking from balcony as another person walks dog',
#   'Two people look over a terrace wall .'],
#  '1389264266_8170bc1c54.jpg': ['Two young girls wearing goth clothes .',
#   'Two girls facing each other one has a skull face bag wearing a red and black shirt , the other is wearing a beaded belt .',
#   'A girl with pink streaked hair and fur uggs looks back while the girl walking next to her looks at her .',
#   'Two girls wearing goth trendy clothing while one looks back at the camera .',
#   'Two girls walking down the street .'],
#  '1396064003_3fd949c9dd.jpg': ['an upside down man doing a flip on a waterski board',
#   'A man hangs upside in the air over the water .',
#   'A person did a side flip while water boarding .',
#   'A person upside down on a water board .',
#   'A wakeboarder performs a flip while being towed at high speed .'],
#  '141140165_9002a04f19.jpg': ['Two boys on oppsite sides of the baseball teams arguing with each other at a base .',
#   'A young baseball player is pointing a finger in the face of a player on the other team .',
#   'a little league player points to another player .',
#   'Two little league players are next to a base in the field .',
#   'A little boy points to the face of another little boy in base in a baseball game .'],
#  '1414820925_3504c394e1.jpg': ['A man in red swim trunks playing volleyball .',
#   'A man in red shorts jumps behind a volleyball net .',
#   'A man in red shorts jumping in back of a volleyball net .',
#   'Athletic man spiking volleyball .',
#   'Guy in red shorts jumping up in front of volleyball net'],
#  '1428641354_f7453afbea.jpg': ['A woman in a white shirt prepares a large meal of hamburgers .',
#   'A woman and a boy are making hamburgers in the kitchen .',
#   'The woman has a blue shirt on with a kid to her side , and she is making hamburgers .',
#   'Woman and young boy stand in a kitchen with a spread of burgers in front of them .',
#   'A woman is holding a jar of mustard and a boy is looking at a tray of hamburgers .'],
#  '143552697_af27e9acf5.jpg': ['A man with helmet and backpack standing on dirt bike in a hilly grassy area .',
#   'A person rides a motorbike through a grassy field .',
#   'The biker is riding through a grassy plain .',
#   'Man on motorcycle riding in dry field wearing a helmet and backpack',
#   'A man riding his bike on a hill .'],
#  '143688283_a96ded20f1.jpg': ['A man with a white shirt and helmet is climbing a mountain .',
#   'A man in a white shirt and helmet is using climbing equipment .',
#   'a young man wearing a white helmet climbing up a rock wall',
#   'a man in a harness climbing a rock wall',
#   'Man rock climbing looking up the rock'],
#  '1439282131_3814d6ae04.jpg': ['Two dogs in the water fighting over a stick .',
#   'Two dogs are holding the same stick in their mouths while in the water .',
#   'Two dogs swimming with a stick .',
#   'The two dogs are in the water retrieving a stick .',
#   'Two dogs in the surf holding on to the same stick .'],
#  '1446933195_8fe9725d62.jpg': ['A black puppy is biting a tree limb .',
#   'A puppy dog is playing with a branch .',
#   'A young brown puppy pulls a leafy branch in his teeth in a backyard .',
#   'A puppy is gnawing on a plant branch in an uncut grassy area with wood and a barrel nearby .',
#   'A brown puppy chewing on a tree branch .'],
#  '1452361926_6d8c535e32.jpg': ['The child sits in a toy car and drinks from a sippy cup .',
#   'A boy sits in a toy car while drinking from his sippy cup .',
#   'A toddler in a red toy car drinks from a juice cup',
#   'A toddler drinking from a cup in a toy car .',
#   'The boy sits in his toy car sipping from a cup .'],
#  '1453366750_6e8cf601bf.jpg': ['Two children are shown upside down .',
#   'Two women are laying upside down on a white bed .',
#   'Two teen girls hang playfully from the side of the bed',
#   'Two kids laying on a bed upside down',
#   'Two girls lay upside down on their bed .'],
#  '1454841725_4b6e6199e2.jpg': ['Some young girls standing in a group some with their arms around each other .',
#   'Four young girls pose for a picture at school',
#   'Four young girls posing for the camera .',
#   'a group of young girls smiling with a large crowd behind them',
#   'Four girls pose in front of a crowd .'],
#  '1461667284_041c8a2475.jpg': ['Four people performing music outdoors .',
#   'A guitarist plays while people play with hula-hoops in the background .',
#   'A guitarist sits playing before microphones , while a man and a boy dance and a woman stands by .',
#   'A man plays guitar on a stage while another woman smiles',
#   'A man in a white hat plays guitar on a stage .'],
#  '1463732807_0cdf4f22c7.jpg': ['Boy posing for camera',
#   'A young boy makes a meditational pose on a swing .',
#   'A boy on a playground swing strikes a medatative pose .',
#   'A boy on a swing wearing a green shirt is making hand gestures .',
#   'Boy in green shirt sitting in swing with eyes closed and making gesture with hands .'],
#  '1472653060_7427d2865a.jpg': ['A man is cutting up food to put in bowls of food at a food court .',
#   'A young man preparing food with diners in the background',
#   'A young man in a black and red t-shirt preparing food on a yellow cutting board .',
#   'A man cutting up some food on a yellow board .',
#   'Asian man is preparing breaded shimp with diners visible at a counter behind him , at a food court in a shopping mall .'],
#  '1473618073_7db56a5237.jpg': ['A little boy sitting on a green swing .',
#   'Boy swinging on a swing set .',
#   'A boy on a green plastic swing .',
#   'A smiling boy plays on a green plastic swing-toy .',
#   'Little boy riding on green swing in a playground .'],
#  '1489286545_8df476fa26.jpg': ['A man and his dog watch the sunset from a bench .',
#   'a man holds his dog near a pond .',
#   'A man sits on a bench holding his dog and looking at the water .',
#   'A man holding a dog sitting on a bench overlooking a lake .',
#   'A man and a dog sit on a bench near a body of water .'],
#  '1501985304_8c50093004.jpg': ['A young boy jumps into the water as a woman holds his arms .',
#   'A child swims with a woman .',
#   'A small child gets into a pool with help from a woman .',
#   'The little boy is in the swimming pool with an adult woman .',
#   'A young curly brown headed boy is jumping into the arms of a woman in a pool .'],
#  '1507563902_6ec8d5d822.jpg': ['A girl is doing a trick on a blue trampoline and is in the air .',
#   'An upside-down child above a trampoline .',
#   'a child is doing a back flip whilst jumping on a trampoline .',
#   'A person is upside down in the air above a trampoline outside .',
#   'Someone is flipping on a blue trampoline .'],
#  '1511807116_41c3645e8c.jpg': ['Two puppies are wrestling on green grass .',
#   'Two dogs wrestle in the ground .',
#   'Two puppies wrestle with each other',
#   'A black dog plays with another animal .',
#   'Two dogs wrestle in the grass .'],
#  '1517340899_ee1c74a8f6.jpg': ['The girl in a pink shirt jumps high over the grass .',
#   'A young blonde girl with a pink shirt on jumps high into the air while kicking her foot out and sticking her tongue out .',
#   'A girl jumps in the grass .',
#   'The blond girl is jumping up in the air .',
#   'A girl jumping in the grass .'],
#  '152029243_b3582c36fa.jpg': ['A young man is in a stream with his dirt bike .',
#   'BMX biker in shallow stream with current performing a wheelie',
#   'A man maneuvers a motorcycle through a rocky stream .',
#   'A motorcycle rider navigating his bike over a stone obstacle .',
#   'The man is dirt bike riding is the stream and climbing the rocks on the bank of the water .'],
#  '1528205014_1323aa9dfd.jpg': ['A man in a yellow shirt wearing multi-colored plastic jewelry .',
#   'The man wearing a colorful outfit is holding something in both hands and smiling for the camera .',
#   'Black man poses for photo .',
#   'A man is wearing a rainbow colored necklace and smiling .',
#   'A man in a yellow jacket with many colorful wristbands is smiling .'],
#  '1529044279_4922ead27c.jpg': ['A crowded street in Europe .',
#   'A group of adults and children , with one man pointing at something off-camera .',
#   'A man holding a little girl hand bends over and points something to her .',
#   'People with small children on a brick ground , one man points to something for a child to see .',
#   'A young girl and an older gentleman hold hands as he points to something off frame .'],
#  '1539166395_0cdc0accee.jpg': ['A little girl with curly hair sitting on a teeter totter .',
#   'A small child with curly hair is on a riding toy .',
#   'A child with a skull on his shirt is sitting in front of some plants and a building and is holding onto handlebars .',
#   'A curly-haired child in a white t-shirt grasps the handlebars of a riding toy .',
#   'A young girl with curly hair with a white shirt with a skull and bones picture on it .'],
#  '1557451043_f5c91ff6f4.jpg': ['The girl in the blue dress and the baseball cap is sitting near the ocean .',
#   'A girl is sitting on the beach and staring at the ocean .',
#   'A woman sits on a rocky beach looking a yellow object in the water .',
#   'The woman is looking out on the beach .',
#   'A woman in a dress and baseball cap sits next to the water .'],
#  '1563731247_7f21d8bec0.jpg': ['Little girl buried in hay throwing hay around at a lady .',
#   'The girls play in the pumpkin patch .',
#   'A child plays on the ground in a pile of leaves .',
#   'a little girl is playing in the hay .',
#   'Two children are playing in a pile of hay with the sun shining overhead .'],
#  '1580172290_e19067e0dd.jpg': ['Two children on hands and knees on a wood floor .',
#   'A young boy crawls with a toddler .',
#   'A baby and a young boy playing .',
#   'two young babies crawling on a wood floor',
#   'Two kids play on the floor .'],
#  '1659358133_95cd1027bd.jpg': ['The dog is standing outside on a tree stump .',
#   'a brown dog sniffs a tree stump .',
#   'Dog sniffing recently cut tree stump .',
#   'A dog sniffs a newly cut tree trunk .',
#   'A dog sniffs a tree stump .'],
#  '166507476_9be5b9852a.jpg': ['Two lizards fighting .',
#   'Two oriental lizards are fighting for dominance in a small pond',
#   'The iguanas wrestled along the rocky water bank .',
#   'Two lizards fight in the water .',
#   'The two reptiles are standing on their back legs near deep water .'],
#  '167295035_336f5f5f27.jpg': ['a lone climber wearing a white helmet climbing a wall .',
#   'The rock climber looks down from above .',
#   'The man in a blue shirt , wearing a helmet , is readying to climb .',
#   'A man wearing blue climbs a steep cliff .',
#   'A climber wearing a white helmet is perched on the side of a rock face .'],
#  '169490297_b6ff13632a.jpg': ['A boy in a blue , yellow , and orange shirt plays outside .',
#   'The boy in the blue and yellow top is standing with arms outstretched .',
#   'A boy in a blue , yellow , and orange shirt holding his arms out from his sides .',
#   'A child with a brightly colored shirt plays outside .',
#   'A boy looks down and spreads his arms wide'],
#  '1776981714_5b224d0f7a.jpg': ['two Asian women walking in front of a green door',
#   'Two girls are walking along the street and talking .',
#   'two women walk down the street .',
#   'Two women walk down a street .',
#   'Two women walking down the street'],
#  '1797507760_384744fb34.jpg': ['Topless men walking up a rocky path .',
#   'The hikers are climbing up the mountains .',
#   'Four shirtless men are hiking up a canyon .',
#   'Four shirtless men hike up a canyon .',
#   'Shirtless men hike through a canyon .'],
#  '181415975_2627aa6668.jpg': ['a blond man jumping through the air over the ocean',
#   'A man gets air time on his wakeboard .',
#   'Man airborne on wakeboard with elevation in the background and blue water .',
#   'A blonde man is wakeboarding and is jumping into the air .',
#   'A blond man on a single waterski .'],
#  '1859941832_7faf6e5fa9.jpg': ['The white dog has a grey Frisbee in its mouth .',
#   'A pitbull jumps to catch a flying disc .',
#   'A dog catches a Frisbee as it jumps on the grass .',
#   'The dog jumps to catch the Frisbee .',
#   'A white dog has jumped up in the air to catch a Frisbee .'],
#  '186890601_8a6b0f1769.jpg': ['This man is swinging on the rope swing out over the blue water .',
#   'A man in red shorts swinging on a rope over a lake .',
#   'A man in a maroon bathing suit swings on a rope on a lake .',
#   'A man is swinging on a rope over water .',
#   'A man is swinging on a rope above the water .'],
#  '1876536922_8fdf8d7028.jpg': ['Two dogs carry a toy out of the ocean .',
#   'Two dogs carry one object while wading in the ocean .',
#   'Two dogs carrying a red toy in their mouths and running in water .',
#   'Two dogs are running through water carrying a rope and red float in their mouths .',
#   'Two dogs run through the water and both hold the same toy in their mouths .'],
#  '1897025969_0c41688fa6.jpg': ['A black dog and a white dog are wrestling on the ground .',
#   'two dogs fight .',
#   'A black dog and a tan dog fighting .',
#   'Two dogs , one white and one black , play with each other in the sand .',
#   'A black dog bites a white dog while standing on the sand .'],
#  '1928319708_ccf1f4ee72.jpg': ['Man cycles through diry bike path wearing white helmet and gloves',
#   'A man is cycling on the road .',
#   'A man rides his bicycle on a wet road .',
#   'A person biking on a road near a fence .',
#   'A man rides a bicycle down a road with concrete barriers .'],
#  '1932161768_996eadac87.jpg': ['A white dog jumps over a log outside .',
#   'A small white dog climbs over a log .',
#   'a small dog steps onto a log .',
#   'A small white dog with a blue collar is climbing over a large log .',
#   'A white terrior is jumping over a log .'],
#  '1956678973_223cb1b847.jpg': ['Three kids jumping in leaves .',
#   'Small children are playing in a pile of dead leaves .',
#   'Four boys in red are playing with fallen leaves .',
#   'Several children leaping into a pile of leaves on the ground .',
#   'Children in red shirts play in the leaves .'],
#  '195962790_3380aea352.jpg': ['A woman sits with her feet in a shallow pool and looks at a puppy .',
#   'Woman and dog cooling off at fountain',
#   'A woman sits by the pool with a dog while another dog is nearby .',
#   'While the humans put their feet into the fountain , the puppy on the side with his master checks out the muzzle leash on the large rottweiler .',
#   'A woman in a purple shirt and a brown puppy sit near a fountain'],
#  '1982852140_56425fa7a2.jpg': ['An adult and a child run on the beach .',
#   'Two people running on a beach .',
#   'A woman and a little girl playing in the sand next to the ocean',
#   'Two people run down the beach and one of them is pointing .',
#   'two people running on the shore of a beach'],
#  '1998457059_c9ac9a1e1a.jpg': ['a body boarder is being dumped on the beach by a wave whilst other surfers are standing around in the water .',
#   'People surfboarding and standing in the ocean .',
#   'Four swimmers in the crystal blue ocean with yellow surfboards .',
#   'A child is pushed by a large wave while holding his yellow surfboard .',
#   'some wakeboarders riding waves on a beach busy with tourists'],
#  '2021613437_d99731f986.jpg': ['A boy dribbling a basketball in a gym .',
#   'A boy dribbles a basketball in the gymnasium .',
#   'A child in a gray t-shirt is bouncing a basketball on a basketball court .',
#   'A boy wearing a Steve Nash shirt dribbles a basketball on an indoor court .',
#   'One little boy dribbles his basketball .'],
#  '2029280005_a19609c81a.jpg': ['A man is inline skating in front of a wooden bench .',
#   'A man on Rollerblades travelling down the sidewalk .',
#   'A man wearing a black shirt and brown pants skates on a concrete surface near a park bench .',
#   'a man in a black shirt is rollerblading past a bench in the city .',
#   'A man is wearing Rollerblades standing on a paved area near a park bench .'],
#  '2055646179_169807fed4.jpg': ['A child is playing with a water spout outdoors while the rest of his family watches .',
#   'A boy holding a hose next to a man while another boy watches on , held by a woman .',
#   'A young child plays with a hose in a field with another child , and two adults .',
#   'A smiling family congregate around a water spout in a pasture .',
#   'A man in an orange shirt is helping a boy squirt water from a hose into a pond whilst a woman and boy watch .'],
#  '2064780645_8f28a1529f.jpg': ['A group of people standing in front of a setting sun .',
#   'Children in a field at dusk .',
#   'Several people are standing near trees at dusk .',
#   'The sun is setting behind a group of people .',
#   'The setting sun outlines a group of four people and the surrounding trees .'],
#  '2065309381_705b774f51.jpg': ['Snowboarder going down a fresh hill .',
#   'The sun is shining above the snow and trees .',
#   'A snowboarder coasting down the side of a snowy hill .',
#   'A man snowboarding down a mountain covered with snow .',
#   'A skier rapidly descending a steep snow covered hill .'],
#  '2071309418_1d7580b0f0.jpg': ['A white dog wearing reindeer ears is next to a brown dog .',
#   'A white dog wearing a christmas reindeer headband plays with a brown dog in the grass among some stuffed animals .',
#   'The white dog next to the brown dog is wearing a christmas headband .',
#   'Two dogs , one wearing christmas antlers , tussle on the grass .',
#   'A white dog with fake antlers on its head and a brown dog play together outdoors .'],
#  '207237775_fa0a15c6fe.jpg': ['One person does a flip in the middle of the field while their friend takes a picture .',
#   'A young man takes a picture of his friend doing gymnastics in a field',
#   'One man taking a photo of another man jumping in a field by a small tree .',
#   'A man doing a back flip while another takes a picture .',
#   'A person is taking a picture of another person doing a flip in midair in the grass .'],
#  '2073105823_6dacade004.jpg': ['A snowboarder rides down a handrail without snow .',
#   'a person is sliding down a brick rail on a snowboard .',
#   'A man skateboards down a steep railing next to some steps .',
#   'A man in a black hoodie and jeans skateboards down a railing .',
#   'A person walks down the brick railing near a set of steps .'],
#  '2080033499_6be742f483.jpg': ['Dog on leash running from man',
#   'A tan dog on a leash stands on his hind legs .',
#   'A brown dog with a lease is running with a person behind the dog .',
#   'A man is walking behind a dog that is standing on its hind legs .',
#   'A brown dog is running away from his owner .'],
#  '2092870249_90e3f1855b.jpg': ['A man looks under a car on a wet street .',
#   'A man works on a car .',
#   'A person lies half under a car , face-down .',
#   'A man lies on a street with his head and shoulders under a parked car that is jacked up .',
#   'A person underneath a car with a jack .'],
#  '209605542_ca9cc52e7b.jpg': ['Man in red headband climbing a rock',
#   'a man with a red headband climbing a rock cliff looming over greenery .',
#   'a climber wearing a red headband is pulling himself up some grey rocks high above some green foliage .',
#   'Man climbing a sheet rock face .',
#   'A man in a headband climbing a rock .'],
#  '2107837987_ffecfc367a.jpg': ['A child in a blue shirt is holding something in his hand on a lake shore .',
#   'The little boy is at the side of the river throwing rocks .',
#   'A little boy is ready to throw a stone into the water .',
#   'A skips rocks near a bridge .',
#   'A boy stands near water with a stone in his hand .'],
#  '2110898123_07729c1461.jpg': ['A dog wearing a red cape runs quickly across a field .',
#   'A brown dog wearing a red vest is running in the grass .',
#   'The brown dog is running on the grass whilst wearing an orange jacket .',
#   'a dog sprints across the grass .',
#   'A brown dog wearing a red vest is running through the grass .'],
#  '2120571547_05cd56de85.jpg': ['A woman is stretching he legs across three seats on a subway train .',
#   'Two women in winter clothes ride in a subway car with orange and yellow seats .',
#   'A woman sites with her feet on the seats in a subway car .',
#   'Two women sit on a city train .',
#   'A woman in black sitting on a train .'],
#  '2135502491_a15c6b5eae.jpg': ['A St Bernard lunges through the snow .',
#   'St Bernard dog running in the snowy field .',
#   'Large St Bernard dog wearing red collar galloping through the snow .',
#   'The large brown and white dog is running through the snow .',
#   'A beautiful brown and white St Bernard running in the snow'],
#  '2141065212_463a6997e1.jpg': ['An elderly man is wearing a black jacket covered in sponsorship logos .',
#   'A man wears a NASCAR jacket .',
#   'A man wearing a black hat and coat makes a face with a crowd behind him .',
#   'The white haired man in the black baseball cap is wearing a black jacket covered with car racing emblems .',
#   'Older man with glasses wearing a car racing hat and jacket .'],
#  '2142232919_c857a09dd7.jpg': ['A black dog carries an orange ball , walking on the ground covered in leaves .',
#   'A black lab puppy runs with an orange ball on an autumn day .',
#   'A black dog with an orange toy in its mouth is walking in fall leaves .',
#   'Black dog with orange ball approaches camera across dead leaves .',
#   'The black dog walks through brown leaves with an orange ball .'],
#  '217583047_5e93e1e119.jpg': ['A man is riding in a boat on the water .',
#   'A man in his boat on the lake',
#   'A man in a white boat is rowing through fog .',
#   'A man sits in a rowboat alone on foggy water .',
#   'Man in a small white boat on a lake .'],
#  '2180480870_dcaf5ac0df.jpg': ['The large , brownish dog is running through a grassy area .',
#   'a little brown dog running through a field of grass',
#   'A dog runs through the grass .',
#   'A brown dog is about to jump .',
#   'Tan dog running through long grass in a park-like setting .'],
#  '2182050469_1edac0bc60.jpg': ['a single person squated down at the edge of a pier overlooking a lake',
#   'A person crouches at the end of a dock on a lake .',
#   'A person is squatting at the end of a pier near a lake .',
#   'A person with a red backpack squatting at the end of a dock .',
#   'I am squatting on a dock , looking into a lake .'],
#  '2192026581_b782d1355a.jpg': ['A group of children in the ocean .',
#   'A group of youngsters swim in lake water',
#   'Many children are playing and swimming in the water .',
#   'A bunch of people swimming in water .',
#   'Several people swim in a body of water .'],
#  '2219959872_988e6d498e.jpg': ['A man and two kids standing in front of an ancient building .',
#   'A man wearing a sleeveless shirt and sunglasses standing next to two children .',
#   'A man in a red muscle shirt poses for a picture beside a stone building whilst other people pass by .',
#   'A man in a red shirt is standing with two fitls in front of an old structure .',
#   'A man poses outside a tourist location .'],
#  '2226534154_cbcab7ba32.jpg': ['People are gathered at a bar .',
#   'A woman in a purple dress rubs her head as other people look on .',
#   'Woman at bar looks on at another woman being approached by a man',
#   'A woman in a purple dress plays with her hair while waiting in a lobby .',
#   'The woman in the purple dress is looking towards the people at the door with her hand running through her hair .'],
#  '222878446_32c6fc4bc9.jpg': ['Two bald men on a park bench wearing small yellow traffic cones .',
#   'Two men wearing cone hats sit on a wooden bench .',
#   'Two dads take a break at the birthday party .',
#   'Two men with strange hats sit on a bench .',
#   'Two men wearing yellow caution cones as hats and one is about to get hit with a ball to the head .'],
#  '2239938351_43c73c887c.jpg': ['Three dogs on grass , one with a blue ball in its mouth .',
#   'A black doberman , a brown and white corgi and a black , brown and white corgi play with a blue ball on the grass .',
#   'A big black dog carries a blue ball while two Corgis run at his side .',
#   'Three dogs , one of whom has a blue ball .',
#   'Three dogs playing with a blue ball .'],
#  '2242863004_3a9f82a31f.jpg': ['A German shepherd is playing with a red ball .',
#   'a German Sheppard dog bting a large red ball',
#   'A German Shepherd is playing with a red ball .',
#   'A dog attempting to chew on a red ball .',
#   'A dog with a red ball .'],
#  '224702241_05af393148.jpg': ['Brown dog walks through river between snowbanks .',
#   'A blond dog walks in a creek with banks filled with snow .',
#   'A blonde dog makes his way up an icy stream with snow piled up on the sides .',
#   'A tan dog walks down a stream between mounds of snow .',
#   'The dog walks through the cold water .'],
#  '2247192427_5e106f24a9.jpg': ['four young boys play basketball .',
#   'Three small boys play basketball indoors .',
#   'Several children are playing a basketball game on a basketball court .',
#   'Three small boys playing basketball .',
#   'Children play basketball on a court .'],
#  '2251747182_6b67a3ab8b.jpg': ['The little boy in the red shorts is going to shoot a basket .',
#   'A young boy holding a basketball about to shoot .',
#   'A boy playing basketball in a gym',
#   'The boy in the white jersey is dribbling the orange Wizards basketball .',
#   'A young boy , playing basketball , is getting ready to take a shot .'],
#  '2255332561_3375897ff0.jpg': ['a lone man climbing the side of a large rock wall .',
#   'The man is on the mountainside .',
#   'A person stands atop a rock face .',
#   'A man stands on the rocky ledge of a large cliff .',
#   'A man is on the side of a mountain and hiking around huge rocks .'],
#  '2256218522_53b92bcbb2.jpg': ['A dog bounding across the sandy landscape in front of people watching .',
#   'A black and white dog is running through the sand at a beach .',
#   'A black and white dog playing in the sand .',
#   'Black dog running across dirt .',
#   'A dog lunges across a beach .'],
#  '225909073_25c3c33a29.jpg': ['A wet dog runs through the surf at a beach .',
#   'A black and brown dog is running out of the surf .',
#   'A wet German Shepherd dog is running out of the ocean with a ball in its mouth .',
#   'The German Shepherd is walking in the body of water .',
#   'German shepherd running in ocean surf'],
#  '2260560631_09093be4c6.jpg': ['The furry dog is running through a grassy wooded area .',
#   'A dirty dogs runs through the woods .',
#   'A dog jumping over a stick in the yard .',
#   'A dog carries a stick through the woods .',
#   'A dog jumps over a stick in a forest .'],
#  '2265100168_175f8218af.jpg': ['A laughing boy lies on a pit of blue balls .',
#   'A pale boy playing in a pit of blue balls .',
#   'Two children are playing in a bin of plastic balls .',
#   'A young boy plays in a red ball pit .',
#   'Blonde boy in red shirt plays inside inflatable with blue balls .'],
#  '2273871383_1ddb3562ea.jpg': ['An older gentleman in brown gives a look of astonishment to the camera .',
#   'An older man standing by a younger man with earphones',
#   'An older man confronts the camera while a young man in a blue jacket looks on .',
#   'A older man in beige stands near a younger man in blue in front of a building .',
#   'An elderly man standing near a younger man .'],
#  '2295894587_2fd8faf550.jpg': ['White dog with mouth open running in the snow .',
#   'The white dog is hard to see in the snow as it runs payfully .',
#   'A small white dog in the snow .',
#   'A white dog running across the snow .',
#   'A white dog is running through the snow .'],
#  '2309327462_82a24538d4.jpg': ['Two dogs are playing in a fenced in area of gravel .',
#   'Two dogs walk over the gravel yard inside a gated area .',
#   'a dog chases another dog .',
#   'Two dogs run in a gravel lot with a fence in the foreground .',
#   'The white and brown dog is shaking its ears .'],
#  '2318502106_33f2e4b4fc.jpg': ['A young man in swim trunks is juggling on the beach .',
#   'A man in swim trunks is juggling on the beach',
#   'A shirtness man juggles batons on the beach .',
#   'A man juggles at the beach .',
#   'Juggler on beach in blue swimsuit .'],
#  '233242340_09963100a3.jpg': ['The black and white dog ran down the ramp .',
#   'A dog climbs down a black ramp',
#   'A brown , black and white dog is on a obstacle course .',
#   'A dog is running down a black and yellow ramp in an obstacle course .',
#   'A dog walks down a black ramp .'],
#  '2332986053_864db84971.jpg': ['A man with a blue helmet and orange shirt .',
#   'A man in an orange shirt and a blue hardhat smiles .',
#   'A man wearing an orange shirt and helmet .',
#   'A man wearing a helmet and sunglasses smiles .',
#   'A man smiling with a helmet on his head .'],
#  '233327292_3bcbc3783f.jpg': ['Man removing garter during wedding',
#   'A man putting a garter on a woman .',
#   'A man in a grey suit kneels in front of a woman in a white dress .',
#   'a woman sitting in a chair while a man is removing her garter belt',
#   'A man is removing a garter for a lady .'],
#  '2337809114_899ba61330.jpg': ['Two young children are playing with a teenage girl who is blindfolded .',
#   "A boy and girl are placing a red blindfold over a woman 's eyes .",
#   'A girl is blindfolded by a young boy and girl .',
#   'A person being blindfolded by a girl and a boy .',
#   'Three kids play , one is blindfolded .'],
#  '2339573065_91f1e3be60.jpg': ['a broen haired woman wearing a black coat with coffee in her hand',
#   'A girl holds her iced drink in her gloved-hand with a look of concentration on her face .',
#   'Woman in black with beverage , with blurry urban background .',
#   'This woman is dressed in black and holding a cup .',
#   'A woman in black holding a cup of ice cream .'],
#  '236144859_52f9e38885.jpg': ['A dog nurses her puppies .',
#   'A black dog nurses white puppies .',
#   'Black dog with white puppies laying on the floor .',
#   'A black dog nursing black and white puppies .',
#   'Black dog with white puppies .'],
#  '2362377137_9528692825.jpg': ['People are gathered on a city street with police vehicles arriving .',
#   'A crowd scene in a downtown area .',
#   "An opposite side street-shot of Applebee 's and Dave and Buster 's restaurants .",
#   'A group of people on the sidewalk of a city street .',
#   'A busy city street with neon lights , lots of people and traffic .'],
#  '2367816288_7c2d11d3c5.jpg': ['A young man doing a flip on the grass .',
#   'Boy doing cartwheels in backyard .',
#   'Young boy in a brown shirt doing a back flip',
#   'A boy cuts a flip in the grass .',
#   'The boy does a flip over a grassy yard .'],
#  '237953705_cfe6999307.jpg': ['Four children having fun outside trying to cover each other in toilet paper .',
#   'The three young children played with some toilet paper in the grass .',
#   'Young children playing in a pile of toilet paper .',
#   'Kids having play fight in toilet paper shreds .',
#   'a group of young children playing in the grass with toilet paper'],
#  '2396025708_e4a72e2558.jpg': ['A man windsurfs in the ocean .',
#   'A man rides large waves on a wind sail .',
#   'A man parasails in the waves ,',
#   'A windsurfer in the waves of the ocean .',
#   'A person parasails on the crest of a wave .'],
#  '2402744031_11f9f2f2b8.jpg': ['Two woman wearing black shoes stand together while a person sits behind them .',
#   'Three women in headscarfs look at somthing out of frame .',
#   'Two women in black coats standing in front of a person sitting on a box on the ground .',
#   'Hooded women at event , one seated next to a table with large glasses on it .',
#   'People shopping at an outdoor marketplace .'],
#  '2404692474_37da774368.jpg': ['the dog barks at the toy .',
#   'A dog runs across the grass to get his toy .',
#   'The light colored dog is chasing after a toy outdoors .',
#   'A dog chasing a toy duck .',
#   'White dog chasing a yellow toy .'],
#  '2407091303_931c918490.jpg': ['A child plays at a playground .',
#   'A little boy stands wide-legged , each foot on each side of the tube slide .',
#   'Boy on playground equipment',
#   'A little boy wearing a red shirt is standing on a slide .',
#   'A young boy climbing in a playhouse'],
#  '2410153942_ba4a136358.jpg': ['This off-roading driver has tipped his truck .',
#   'A man is in a truck that is lying on its side during a truck event .',
#   'A red and white car is overturned on a dirt track .',
#   'a red car has rolled over on a dirt track .',
#   'The vehicle is lying on its side with the driver inside .'],
#  '241046599_28b0ca7b9f.jpg': ['a small brown dog is running across the grass wearing a purple and green coat .',
#   'Brown dog , with green and purple cape , runs on grass .',
#   'A small dog wearing a purple and green cape',
#   'A miniature dachshund has an apron on its back .',
#   'The dog is wearing a purple cape .'],
#  '2411824767_4eb1fae823.jpg': ['A small brown and white dog is jumping over bushels of hay .',
#   'A dog jumps over hay .',
#   'A brown dog is jumping over a grassy mound near to a lake .',
#   'A brown and white dog leaps .',
#   'A corgi jumps off a bale of hay , m water and buildings behind it .'],
#  '241345639_1556a883b1.jpg': ['The two football players in white jerseys and purple pants tackle the player in the red jersey .',
#   'Two football players try to tackle a player of the opposite team .',
#   'Three football players are tackling a red uniformed football player during a football game .',
#   'Three football players in purple uniforms try to tackle a player in a red uniform .',
#   'There is a college player being tackled in a game .'],
#  '241346580_b3c035d65c.jpg': ['Football players avoiding a fumble .',
#   'A red team and a white team are playing football .',
#   'The football player in red is running with the all towards the player in white .',
#   'The football players are wearing red and white , and the crowd is also wearing red and white .',
#   'A group of men play a college football game .'],
#  '241347150_5ff37818c2.jpg': ['The receiver is tackled after making the catch .',
#   'A football player in white is being tackled by a Oklahoma University player .',
#   'A Sooners football player is tackling an opposing player .',
#   'An American footballer in a red outfit is attacking the player in white who is running with the ball , whilst other players are nearby .',
#   'A football player in a purple uniform holds the ball while a player in red tries to tackle him .'],
#  '241347300_7c84ecf764.jpg': ['A football player being tackled from behind by another player from a different team in front of a crowd .',
#   'A football player in red being tackled by opponents in white .',
#   'A football player in a Sooners jersey , runs down a field with a large crowd in the background .',
#   'A football tackle in progress with a crowd in the background .',
#   'A football player wearing a number 23 white jersey tackles a football player wearing a red , number three jersey while fans cheer .'],
#  '241347441_d3dd9b129f.jpg': ['The football player dressed in red looks down field .',
#   'A football player in a Sooners uniform .',
#   'A football player for the Sooners is preparing for the next play during a game .',
#   'A football player wearing a Sooners uniform with the number 42 .',
#   'A man in a red football uniform prepares to play .'],
#  '241347611_cb265be138.jpg': ['A team manager out on the football field during a game .',
#   'A coach in a white polo shirt on a football field',
#   'A football coach is walking on a football field .',
#   'A man on the coaching staff for OU has sunglasses on his head during a football game .',
#   'A man in a white shirt is walking on a football field in front of some players .'],
#  '241347635_e691395c2f.jpg': ['The man with the white pants and blue Nike shirt has a whistle around his neck .',
#   'A man is walking along a field .',
#   'A man walks down a field with a crowd in the stands behind him .',
#   'The head coach is walking out on the field .',
#   'A man in sunglasses , blue shirt and beige pants walks across an athletic field .'],
#  '2419591925_1038c6c570.jpg': ['A little boy climbing over a chain fence .',
#   'A boy in a brown jacket is standing on chains between two wooden posts .',
#   'Boy climbing on a chain fence .',
#   'A child standing on a heavy chain fence at a dock .',
#   'A little boy standing and playing on a chained fence .'],
#  '2423138514_950f79e432.jpg': ['Two naked boys smiling and playing .',
#   'Two young , naked boys are wet , while one raises his arm .',
#   'Two naked boys at a pool .',
#   'Two naked children , one with a mark on his chest .',
#   'Two naked young boys play in the water .'],
#  '2429272699_8a9699775e.jpg': ['A man walks down the street .',
#   'a man wearing black , walks down the street .',
#   'A man in a striped scarf walking down the sidewalk .',
#   'A young man wearing jeans and jacket walking down a street .',
#   'A man in black with a scarf walks down a street .'],
#  '2432061076_0955d52854.jpg': ['The large brown and white dog splashes on the shore .',
#   'Tan and white dog running in water .',
#   'A brown dog runs through the water on a beach .',
#   'A dog in the water near the beach with an urban horizon behind .',
#   'A dog running in the surf .'],
#  '2432709509_2a4d0c833f.jpg': ['A young boy sitting is a field with a drain pipe in the background .',
#   'Baby by sewer drain cries',
#   'A child is sitting on the grass by a concrete storm drain .',
#   'A child is crying in a low cut field with a drainage pipe nearby .',
#   'The young child is sitting on the grass in a park .'],
#  '2437266971_b91a8f9a00.jpg': ['A man hands out fliers while wearing a mask .',
#   'A man in a button up shirt and tie is wearing a smiling mask .',
#   'A man in a blue shirt and tie is wearing a white mask whilst handing out papers .',
#   'A masked man in blue shirt and a tie holding papers in front of him .',
#   'Man in business attire with Guy Fawkes mask holding paper at protest .'],
#  '2444821454_22a346c996.jpg': ['A black and white dog is in the grass with a red striped disk .',
#   'a black and white dog jumping in the grass after a Frisbee .',
#   'A dog jumping for a Frisbee in a field .',
#   'A black and white dog jumps in the air near a red Frisbee .',
#   'A dog is on his hind legs and a Frisbee is near the ground .'],
#  '2445283938_ff477c7952.jpg': ['The young girls sat in a circle on the wood floor .',
#   'A group of girls sit back to back .',
#   'Little girl in bare feet sitting in a circle .',
#   'a group of girls sitting in a circle',
#   'Little girls sitting in a circle on wooden floor surrounded by observer area .'],
#  '2448793019_5881c025f9.jpg': ['Distorted photograph of a child at the bottom of a slide .',
#   'A small child at the bottom of a slide has hair sticking up .',
#   'A young child wearing sunglasses is at the base of a blue slide .',
#   'a young child in blue jeans sliding down a blue slide',
#   'A child with wild hair and sunglasses getting off a blue slide .'],
#  '2451114871_8617ae2f16.jpg': ['Dogs run at a dog racetrack .',
#   'Greyhounds racing chasing a mechanical rabbit around the track .',
#   'Four dogs race around a turn .',
#   'Dogs with muzzles are racing around a sandy track .',
#   'Four dogs in blue , green , red and black jerseys are racing .'],
#  '2455528149_6c3477fd33.jpg': ['A man with a basket is walking through an are gallery .',
#   'A delivery man is passing by two people at an art gallery .',
#   'People admiring paintings on the street .',
#   'A man and woman are looking at artwork that is on easels and clipped to a fencing wall .',
#   'Some people are looking at pictures at an art gallery .'],
#  '2458033289_f0616879df.jpg': ['The man with a white beard and blue cap is standing in the doorway of a workshop .',
#   'A man with a beard stands in front of a used tires business .',
#   'A man standing in front of a garage .',
#   'The man at the used tire shop has a white beard .',
#   'A man in a hat standing in front of a tire shop .'],
#  '2460159430_71ab1aacfa.jpg': ['Two dogs running through tall grass .',
#   'A tan dog is bounding through grass .',
#   'A dog running in long grass , a housing development behind it .',
#   'A brown dog races through a field .',
#   'a brown dog running through the tall grass .'],
#  '2462153092_e3f4d8f6a2.jpg': ['A girl runs with dogs in a dry field .',
#   'A girl is running through a field with a brown dog and white dog running beside her .',
#   'A girl in purple pants running with two dogs .',
#   'Girl running through a field with a brown dog and a white dog .',
#   'A girl running outside with three dogs'],
#  '2467850190_07a74d89b7.jpg': ['A dog and a woman bending over .',
#   'a woman and a dog both with the butts turned towards the camera',
#   'A woman and a dog both kneel with their heads down and butt in the air .',
#   'A dog and a person look under the shelf .',
#   'The backs of a woman and a dog .'],
#  '2471974379_a4a4d2b389.jpg': ['Bikers are seen riding during a parade , one has an American flag .',
#   'People on motorcycles ride down a street with an American flag waving .',
#   'A group of motorcycles wearing black .',
#   'Man carrying american flag rides motorbike .',
#   'many motorcyclists ride along the street .'],
#  '2472250097_a3191a94b3.jpg': ['A person stands on a hill surrounded by blue skies and clouds .',
#   'A person with a fishing pole silhouetted in front of a blue sky .',
#   'A silhouette of a man with a fishing pole .',
#   'A person with a fishing pole is backlit against a blue cloudy sky .',
#   'A man carrying a fishing pole silhouetted against a bright blue sky .'],
#  '2473738924_eca928d12f.jpg': ['Two little girls are dressed in white karate uniforms .',
#   'Two girls in karate uniforms struggle in a dojo .',
#   'Two little girls spar in a Karate bout .',
#   'Two little girls practice martial arts .',
#   'Two young girls sparring in white martial arts outfits while a third person watches from the side .'],
#  '2474918824_88660c7757.jpg': ['A man in brown is helping a man in red climb a rock .',
#   'A guy tries to climb a stone cliff while his friend helps him .',
#   'A man in a red shirt climbs a rock while another man stands behind to help him .',
#   'A man in a red shirt is learning how to climb a cliff .',
#   'A man wearing a brown sweatshirt helps a man in red climb a rock .'],
#  '247691240_3881777ab8.jpg': ['A man rock climbing .',
#   'There is a man in a light shirt climbing a rocky cliff .',
#   'A guy is rock climbing .',
# ...
#  '427167162_2c99779444.jpg': ['Group of people fighting on a street .',
#   'a group of men are fighting in front of a bar in a European city , one of them hitting another with a stick .',
#   'Eight men fighting in the street .',
#   'Men fighting in front of a bar .',
#   'A group of people jumping away in a street'],
#  '428483413_b9370baf72.jpg': ['a man and woman walking past a record shop',
#   'a blond girl standing in front of a large metal fan',
#   'A woman with dirty blonde hair and sunglasses and a man with dark hair stand in front of a record store .',
#   'A woman and a man stand outside a store .',
#   'A woman and a man are passing by a window displaying a record .'],
#  '439916996_1ddb9dc8e7.jpg': ['A woman watches a brown dog run away from a house across the grass .',
#   'A woman in a blue jacket watches as her two brown dogs play with a red ball in a grassy yard .',
#   'A woman throws a Frisbee for her two brown dogs to chase .',
#   'brown dogs and a woman in a yard',
#   'A brown dog persues a Frisbee across the grass as the thrower watches .'],
#  '444057017_f1e0fcaef7.jpg': ['A little girl on a piece of playground equipment',
#   'A little girl gets her picture taken while on the merry-go-round .',
#   'A young girl looks up as she rides on a merry-go-round .',
#   'A little girl in pink clothes holding yellow rods .',
#   'A little girl sitting on a playground ride .'],
#  '458183774_afe65abf67.jpg': ['Large dog rolling on its back in green grass .',
#   'Big yellow dog rolling around on the green lawn .',
#   'A large , tan dog is rolling in green grass .',
#   'A large tan dog is rolling around on its back in a yard of grass .',
#   'A dog rolls on his back in the grass .'],
#  '462198798_89e2df0358.jpg': ['A black dog is walking beside water in the woods .',
#   'A black dog and its reflection are seen near a pond ringed by dry foliage .',
#   "A black dog walks along a marsh 's edge .",
#   'A dog is walking near a body of water .',
#   "A big , black dog is walking along the water 's edge ."],
#  '468930779_8008d90e10.jpg': ['closeup of a brown dog in the water holding a very large stick .',
#   'A swimming dog with a small branch in its mouth .',
#   'A brown dog carrying a stick in its mouth .',
#   'A dog swimming with a stick in its mouth .',
#   'A dog has its head coming up from the water as it holds a stick .'],
#  '476233374_e1396998ef.jpg': ['Two little kids play on a pebble covered beach .',
#   'A little boy and a little girl are playing with pebbles on the beach .',
#   'Two young child stand on the rocks near the edge of the water .',
#   "A small boy and girl on the beach 's edge , looking at the ground",
#   'Two kids playing on a pebble beach by the water'],
#  '488549693_a1f51d8c4a.jpg': ['Two children stand with a net by a shallow shore .',
#   'two girls look into the water .',
#   'two kids playing on the beach , close to the water',
#   'Two children are standing on the shore next to a body of water .',
#   'Two children standing at the edge of a river , holding a butterfly-catcher .'],
#  '489372715_ce52da796a.jpg': ['a tan dog shaking its body',
#   'An orange dog shakes his head very hard on the sand .',
#   'A brown dog is shaking his head while standing on sand .',
#   'The orange haired dog shook its head while standing on the beach .',
#   'A brown dog with large ears is shaking its self while standing on sand .'],
#  '492493570_c27237a396.jpg': ['A girl in a pink suit chases a gull on a beach .',
#   'A girl chases a bird across the sand at the edge of the ocean .',
#   'Girl in pink bathing suit with right arm in air behind a seagull on the beach near the water .',
#   'Young girl in red bathing suit feeding a seagull',
#   'The little girl plays along the shoreline as the seagull passes by .'],
#  '498957941_f0eda42787.jpg': ['Little boy running very fast .',
#   'A young boy runs .',
#   'A boy in a blue shirt is running .',
#   'A distorted image of a young boy running',
#   'A little boy running , blurry picture .'],
#  '501650847_b0beba926c.jpg': ['Large gray dog being handed a white soccer ball .',
#   'someone is holding out a punctured ball in front of a brown dog with a red collar .',
#   'A brown dog starring at a soccer ball .',
#   'The owner tries to hand a deflated ball to his dog .',
#   'A man holding out a deflated soccer ball to a grey dog .'],
#  '507758961_e63ca126cc.jpg': ['A little girl with a bow in her hair , doing a push-up on the grass .',
#   'A girl wearing blue goggles on her head makes a face while laying on the grass .',
#   'Child lying in the grass and wearing blue swim goggles on its head .',
#   'A child in a white and orange outfit doing push ups .',
#   'A little girl makes a goofy face and does a half push up in the grass .'],
#  '508261758_78fb8ae067.jpg': ['Three girls playing on the ground .',
#   'Three girls fell on top of one another and are laughing histerically .',
#   'Three young girls play wrestling and laugh a lot .',
#   'Three teenage girls rolling all over each other on the ground , laughing',
#   'Three girls pile on top of each other on the concrete .'],
#  '509778093_21236bb64d.jpg': ['a brown and white dog chasing a ball on some grass .',
#   'a brown and white dog has is playing with a white ball on the grass .',
#   'A orange dog playing with a white ball on green grass .',
#   'A small brown dog paws at a white ball',
#   'A collie plays with a white ball in a field of green grass .'],
#  '513116697_ad0f4dc800.jpg': ['The skier does a flip .',
#   'a lone skier jumping on the side of a snowy mountain .',
#   'A skier doing a flip while jumping .',
#   'The skier does a high flip over snow in the mountains .',
#   'a skier jumps over a gap .'],
#  '514990193_2d2422af2c.jpg': ['A woman is laying on a striped couch on a grassy yard in a residential neighborhood .',
#   'A woman lies down on an old couch sitting on the grass .',
#   'A woman lays on a sofa in a yard .',
#   'Girl poses on couch on suburban lawn .',
#   'There is a couch sitting on grass with a girl in jeans and light brown hair on it .'],
#  '515702827_be3c6ce857.jpg': ['A girl in pink and man in black paddle through water .',
#   'A child in a pink hat on a pink surfboard .',
#   'A man in a black shirt swims next to a girl on a pink surfboard .',
#   'Two children splash through the water , one is wearing a pink swim cap .',
#   'A man swimming beside a girl on a pink body board .'],
#  '519754987_51861fea85.jpg': ['A skinny girl rides by on a bike with a lot of people in the background .',
#   'A young woman riding a bike down a street past a crowd of people .',
#   'A thin young woman in a green t-shirt cycles by a grey car .',
#   'People of all ilks on a busy street .',
#   'A woman riding a bicycle past a car and a group of people on a sidewalk .'],
#  '520491467_54cbc0a866.jpg': ['A little boy and girl are jumping on a trampoline in front of a yellow building .',
#   'Two children jump on a trampoline .',
#   'Two children , a boy and a girl , in the air above a trampoline .',
#   'Two young children Bounce on a short trampoline .',
#   'Two children jumping on a trampoline .'],
#  '521186251_e97d1f50f8.jpg': ['The kids ride a boat in the water .',
#   'Three girls and one boy are holding onto a raft as they are being pulled by a road through the water .',
#   'Several girls on a raft floating in rough waters .',
#   'The four kids are riding a raft on the water .',
#   'four children lay on a tube .'],
#  '530661899_94655d7d0e.jpg': ['Two people backlit with light sky .',
#   'Two people walk on a path as the sun casts a shadow towards the camera .',
#   'A man and women walk atop a hill .',
#   'Two people walk at sunset .',
#   'A couple walking on a dirt road .'],
#  '532999240_1409d073be.jpg': ['The dog runs towards the ball .',
#   'A brown and white dog plays with a ball in the dirt .',
#   'A brown dog jumps as he looks at a soccer ball .',
#   'This brown and white dog is chasing a soccer ball .',
#   'A brown dog is chasing after a soccer ball .'],
#  '534056823_0752303702.jpg': ['A woman poses for pictures with a statue of a troll .',
#   'A girl posing next to a big statue with a big nose .',
#   'A woman having her picture taken in front of a large carving .',
#   'Woman in black shirt posing for pictures in front of statue .',
#   'A woman poses in front of a statue , while a man and another woman photograph her .'],
#  '534313000_4ad39c7ee0.jpg': ['a big black and white dog jumping in a body of water .',
#   'A large brown dog is jumping into a pond .',
#   'The large brown dog jumps into a pond .',
#   'A brown dog leaps over the water in a grassy and tree-lined yard .',
#   'A brown dog is jumping into a pond .'],
#  '535399240_0714a6e950.jpg': ['A girl and a boy enjoy a fast amusement ride .',
#   'A young girl and boy on a ride at an amusement park .',
#   'Two children ride in a red seat on a fair ride and smile .',
#   'Two kids are on a fair ride and are slipping to one side of the car .',
#   'A boy and a girl are riding in a red seat on a fairground ride .'],
#  '542648687_adf13c406b.jpg': ['Two dogs change direction in an uncut field surrounded by low brush .',
#   'Two dogs run in a field looking at an unseen Frisbee .',
#   'two black and white dogs running in a flowery field',
#   'Two black and white dogs look toward something in the air while running in a grassy field .',
#   'Two black and white dogs in a field of flowers and grass .'],
#  '543603259_ef26d9c72d.jpg': ['A woman with a bag stands on a street near a man leaning on a wall .',
#   'an asian woman stands with her messanger bag .',
#   'Women wait on a sidewalk .',
#   'A lady waiting .',
#   'A woman looking away from the camera , and another woman standing next to a wall and by a fence .'],
#  '544301311_5e7d69a517.jpg': ['Two women with white head garb and long dresses sitting in front of a door on steps reading and drinking a beverage .',
#   'Two women in traditional European dress sit on a stoop , one drinking , the other reading .',
#   'Two girls sit by a doorway on the steps .',
#   'Two women in period dress sitting in a doorway .',
#   'The women sit outside on the steps reading and drinking .'],
#  '566794036_60f7acdf35.jpg': ['An athlete in red shorts is caught frozen during a basketball move .',
#   'Man in red shorts bouncing a basketball .',
#   'A shirtless man in red shorts bouncing a basketball on a court .',
#   'A man wearing red shorts dribbles a basketball behind him .',
#   'A man with no shirt plays basketball .'],
#  '566794440_f9ec673a2f.jpg': ['A woman in camouflage and her hair up in a ponytail walks on the field with a black softball glove on one hand .',
#   'girls with baseball gloves walking across a baseball field',
#   'A woman playing baseball walks back to her base while her feamle teammate follows .',
#   'A woman with a glove on a baseball field with another woman',
#   'The girls return to the field during their softball game .'],
#  '639120223_7db6bdb61f.jpg': ['Two workers at a grocery store observing something out of camera range .',
#   'Two grocery store employees talk at a checkstand .',
#   'Two workers at a grocery store .',
#   'Two people are working at a coffee shop',
#   'Two workers in a store are wearing aprons .'],
#  '640053014_549d2f23d2.jpg': ['A motorcyclist is attempting a jump with another motorcyclist nearby as well as onlookers .',
#   'A person in a red , white and blue jumpsuit flying through the air on a yellow motorcycle .',
#   'A person on a yellow dirt bike is taking a jump .',
#   'A person in midair on a yellow motorcycle .',
#   'A cyclist on a neon yellow bike is airborne .'],
#  '69189650_6687da7280.jpg': ['A brown dog is running through the field .',
#   'A brown dog with a collar runs in the dead grass with his tongue hanging out to the side .',
#   'a brown dog with his tongue wagging as he runs through a field',
#   'A dog running in the grass .',
#   'A brown dog is running through a brown field .'],
#  '693164706_9624582e69.jpg': ['A little kid in a red jacket riding a broom like a horse .',
#   'A boy in a red hooded-coat is riding a pool broom like a horse in an empty pool .',
#   'Boy in raincoat straddle stick outside .',
#   'The child in raingear is dragging a broom through a puddle .',
#   'a little boy wearing a raincoat plays with a mop .'],
#  '733172023_5810350af6.jpg': ['There is a sidewalk with a rack of dresses and a girl in jeans and a red shirt .',
#   'A girl in an orange tank top stands outside a cafe .',
#   'a girl standing outside of a clothing shop',
#   'A woman stands outside near a dress shop .',
#   'A woman stands near chairs and tables , outside a store .'],
#  '759015118_4bd3617e60.jpg': ['A little boy walks around with a white t-shirt and black shorts outside .',
#   'A small boy looking at the camera .',
#   'The small boy is walking on a street lined with people .',
#   'A boy in a blue shirt .',
#   'A little boy in a blue shirt looking at the camera , concrete in the background .'],
#  '802594049_289e3c8420.jpg': ['A man with a beard and a navy blue backwards baseball cap stares intently at something in the distance .',
#   'A black man with facial hair wears a navy hat and blue jacket in front of a white background .',
#   'A man wearing a blue baseball cap is gazing into the distance .',
#   'A man wearing a backwards baseball cap .',
#   'A man in blue cap and jacket looks frustrated .'],
#  '808245064_8a7971fc5b.jpg': ['A dark skinned man smoking a cigarette near a green trashcan .',
#   'a man in a blue shirt smoking a cigarette',
#   'A man in a blue shirt is standing outside smoking a cigarette .',
#   'A man stands outside smoking a cigarette',
#   'A man with glasses smokes a cigarette .'],
#  '836768303_d748df5546.jpg': ['Two children in an enclosed dog bed with the dog .',
#   'Two children and a brown dog in a brown tube .',
#   'A small blonde boy and another small child are inside a cushion doghouse with a brown dog .',
#   'Two youn boys lay in a dog house with their dog .',
#   'Two children and a dog are in a bedroll .'],
#  '842960985_91daf0d6ec.jpg': ['Man walking with his umbrella in a bleak street .',
#   'A man in a trench coat is walking with an umbrella .',
#   'A man with white hair , a long trench coat and an umbrella walks past a parking meter .',
#   'A man in a tan trench coat and blue jeans walks with a black umbrella open over his head .',
#   'A man in a beige trench coat is walking in the rain .'],
#  '856985136_649c0a3881.jpg': ['A young woman tries to stick her foot in a fountain .',
#   'A woman in capri jeans crouches on the edge of a fountain with her left foot kicked out to touch the falling water .',
#   'Young blonde woman putting her foot into a water fountain',
#   'Woman balancing on edge of fountain while sticking her toe in the water .',
#   'A girl touches the fountain with her foot .'],
#  '905355838_3a43fdfd4e.jpg': ['A baseball player standing on the field',
#   'A male ballplayer wearing a white and blue uniform playing in front of a large crowd .',
#   'Baseball player looking out into a stadium crowd',
#   'a baseball player stands and faces the crowd .',
#   'A baseball player wearing a number 19 shirt looks at the outfield .'],
#  '967719295_3257695095.jpg': ['A dog leaping into the water near a motorboat .',
#   'A light colored dog jumping off the back of a boat into the water .',
#   'A tan dog jumping off of a boat into the water .',
#   'The yellow dog is jumping off of a ship into the water .',
#   'a dog jumps into the pond .'],
#  '973827791_467d83986e.jpg': ['A woman is throwing a bucket of water over a baby in the paddling pool .',
#   'I child slides into a wading pool full of water while an adult tosses a bucket of water on them .',
#   'A woman is throwing water on a child in a plastic swimming pool in a rural area .',
#   'a woman dumping water on a small child who is in a pool',
#   'A little kid splashes around in the kiddie pool while a lady watches .'],
#  '97406261_5eea044056.jpg': ['The yellow and black cat and the brown and black dog are fighting .',
#   'A multicolor cat fighting with a black and brown dog in a red collar .',
#   'A dog and cat are fighting on a chair .',
#   'A cat swatting at a doberman dog',
#   'A calico cat raising its paws towards a dog with an open mouth']}

# %%
images_test=glob('./validation_data/flickr8k_validation_set_500_images/Images/*.jpg')

# %%
list_of_images_path = list(captions_image.keys())

# %%
def proprocessing(imge):
    img_read=plt.imread(imge)
    img=cv.resize(img_read,(299,299))
    img=preprocess_input(img)
    return np.array(img)

# %%
with open('./models/vocab.pickle','rb') as f:
    tokenizer=pickle.load(f)

# %%
def beam_search(model_cnn,model_rnn,image,beam_size=3):
    images=proprocessing(image)
    dim=np.expand_dims(images,0)
    cnn_model=model_cnn.predict(dim,verbose=1)
    sequnce=[[['startseq'],0.0]]
    for _ in range(40):
        all_condidates=[]
        for seq,score in sequnce:
            if seq[-1]=='endseq':
                all_condidates.append((seq,score))
                continue
            encoder=tokenizer.texts_to_sequences([' '.join(seq)])
            encoder=sequence.pad_sequences(encoder,maxlen=40,padding='post')
            rnn_model=model_rnn.predict([cnn_model,encoder],verbose=0)[0]
            top_k=np.argsort(rnn_model)[-beam_size:]
            for word_indx in top_k:
                word=tokenizer.index_word.get(word_indx)
                if word is None :
                    continue 
                condidate=seq+[word]
                candidate_score = score - np.log(rnn_model[word_indx] + 1e-9)
                all_condidates.append((condidate,candidate_score))
        sequnce=sorted(all_condidates,key=lambda x:x[1])[:beam_size]

    return ' '.join(sequnce[0][0])

# %%
from tensorflow.keras.models import load_model

# %%
rnn,cnn=load_model('./models/caption_model_v1_1_1.h5'),load_model('./models/InceptionEF_model (1).h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
beam_search(cnn,rnn,images_test[0],10)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 'startseq a man wearing a hat and a hat endseq'

# %%
plt.imshow(plt.imread(images_test[0]))
plt.show()

# %%
# Out:
# '1022454428_b6b660a67b.jpg'

# %%
captions_image[os.path.basename(images_test[0])]
# Out:
# ['A man wears an orange hat and glasses .',
#  'A man with glasses is wearing a beer can crocheted hat .',
#  'A man with gauges and glasses is wearing a Blitz hat .',
#  'The man with pierced ears is wearing glasses and an orange hat .',
#  'A man in an orange hat starring at something .']
